# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Admin\Downloads\Quote-Equity-CDSL-EQ-26-06-2023-to-26-09-2023.csv")

# %%
df.head()
# Out:
#          Date  series      OPEN      HIGH       LOW  PREV. CLOSE       ltp   \
# 0  25-Sep-2023      EQ  1,319.00  1,326.05  1,305.05     1,312.90  1,312.90
# 1  22-Sep-2023      EQ  1,300.00  1,321.00  1,279.00     1,291.85  1,316.00
# 2  21-Sep-2023      EQ  1,298.00  1,318.90  1,274.10     1,306.70  1,299.00
# 3  20-Sep-2023      EQ  1,325.00  1,333.00  1,304.00     1,330.20  1,309.90
# 4  18-Sep-2023      EQ  1,344.40  1,351.95  1,326.55     1,344.40  1,330.50
#
#      close      vwap     52W H   52W L   VOLUME             VALUE   \
# 0  1,311.90  1,316.79  1,430.00   880.9  496,195    653,382,681.55
# 1  1,312.90  1,306.61  1,430.00   880.9  838,432  1,095,507,516.85
# 2  1,291.85  1,291.82  1,430.00   880.9  948,071  1,224,735,614.10
# 3  1,306.70  1,313.47  1,430.00   880.9  609,251    800,230,186.45
# 4  1,330.20  1,338.15  1,430.00   880.9  717,750    960,454,559.90
#
#   No of trades
# 0        27,028
# 1        36,401
# 2        45,558
# 3        31,425
# 4        30,997

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63 entries, 25-Sep-2023 to 26-Jun-2023
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   series         63 non-null     object
#  1   OPEN           63 non-null     object
#  2   HIGH           63 non-null     object
#  3   LOW            63 non-null     object
#  4   PREV. CLOSE    63 non-null     object
#  5   ltp            63 non-null     object
#  6   close          63 non-null     object
#  7   vwap           63 non-null     object
#  8   52W H          63 non-null     object
#  9   52W L          63 non-null     float64
#  10  VOLUME         63 non-null     object
#  11  VALUE          63 non-null     object
#  12  No of trades   63 non-null     object
# dtypes: float64(1), object(12)
# memory usage: 6.9+ KB

# %%
x=str(df.index)
